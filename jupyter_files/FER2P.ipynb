# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("../Data_Sets_for_Final_Projects/Feature-Engineering-Root-2-Pandas/161218_3323.csv")
df.sample(n=10)
# Out:
#        ru_id  frame_id  stave_id  chip_id      abs_time  bunch_counter  \
# 5166       1    123497         0        3  7.675330e+08            155
# 7172       1    155097         0        3  2.661370e+09             76
# 22126      1    468464         0        3  4.258020e+09             52
# 24335      1    500408         0        3  1.877780e+09             85
# 2598       1     61370         0        3  1.339860e+09             79
# 3873       1     92409         0        3  3.199320e+09             39
# 18517      1    375056         0        3  2.959670e+09             76
# 13088      1    280101         0        3  1.562620e+09            129
# 3446       1     74740         0        3  2.140620e+09            231
# 19720      1    405910         0        3  5.121040e+08             86
#
#                                                   column  \
# 5166   [485;484;485;485;484;484;485;485;484;485;486;4...
# 7172   [125;125;124;124;125;125;127;127;126;126;127;1...
# ...
